# %%
import pandas as pd
df = pd.read_csv('bestsellers.csv')

# %%
df.drop_duplicates(inplace=True)

df.rename(columns={"Name": "Title", "Year": "Published Year", "User Rating": "Rating"}, inplace=True)

df["Price"] = df["Price"].astype(float)
df["Price"] = df["Price"].round(2)

df["Rating"] = df["Rating"].astype(float)

df = df.sort_values(by='Title')
df
# Out:
#                                                  Title  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  Rating  Reviews  Price  Published Year  \
# 0                    JJ Smith     4.7    17350    8.0            2016
# 1                Stephen King     4.6     2052   22.0            2011
# 2          Jordan B. Peterson     4.7    18979   15.0            2018
# 3               George Orwell     4.7    21424    6.0            2017
# 4    National Geographic Kids     4.8     7665   12.0            2019
# ..                        ...     ...      ...    ...             ...
# 545               Jeff Kinney     4.9     9413    8.0            2019
# 547               Jen Sincero     4.7    14331    8.0            2017
# 548               Jen Sincero     4.7    14331    8.0            2018
# 546               Jen Sincero     4.7    14331    8.0            2016
# 549               Jen Sincero     4.7    14331    8.0            2019
#
#            Genre
# 0    Non Fiction
# 1        Fiction
# 2    Non Fiction
# 3        Fiction
# 4    Non Fiction
# ..           ...
# 545      Fiction
# 547  Non Fiction
# 548  Non Fiction
# 546  Non Fiction
# 549  Non Fiction
#
# [550 rows x 7 columns]

# %%
df.loc[df.Author == 'J. K. Rowling', 'Author'] = 'J.K. Rowling'
df.loc[df.Author == 'Marie KondÅ', 'Author'] = 'Marie Konda'

# %%
df.to_csv("best_sellers_data_cleaned.csv")
# Out:
#                                                  Title  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  Rating  Reviews  Price  Published Year  \
# 0                    JJ Smith     4.7    17350    8.0            2016
# 1                Stephen King     4.6     2052   22.0            2011
# 2          Jordan B. Peterson     4.7    18979   15.0            2018
# 3               George Orwell     4.7    21424    6.0            2017
# 4    National Geographic Kids     4.8     7665   12.0            2019
# ..                        ...     ...      ...    ...             ...
# 545               Jeff Kinney     4.9     9413    8.0            2019
# 547               Jen Sincero     4.7    14331    8.0            2017
# 548               Jen Sincero     4.7    14331    8.0            2018
# 546               Jen Sincero     4.7    14331    8.0            2016
# 549               Jen Sincero     4.7    14331    8.0            2019
#
#            Genre
# 0    Non Fiction
# 1        Fiction
# 2    Non Fiction
# 3        Fiction
# 4    Non Fiction
# ..           ...
# 545      Fiction
# 547  Non Fiction
# 548  Non Fiction
# 546  Non Fiction
# 549  Non Fiction
#
# [550 rows x 7 columns]
